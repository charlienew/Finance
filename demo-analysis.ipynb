# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('D:/data/600000.csv', encoding = 'gb18030')#include special encoder to show Chinese character
df.head(10)
# Out:
#            日期     股票代码    名称    收盘价    最高价    最低价    开盘价    前收盘   涨跌额     涨跌幅  \
# 0  2017-12-29  '600000  浦发银行  12.59  12.62  12.51  12.52  12.54  0.05  0.3987
# 1  2017-12-28  '600000  浦发银行  12.54  12.66  12.53  12.60  12.62 -0.08 -0.6339
# 2  2017-12-27  '600000  浦发银行  12.62  12.66  12.53  12.65  12.64 -0.02 -0.1582
# 3  2017-12-26  '600000  浦发银行  12.64  12.66  12.56  12.57  12.59  0.05  0.3971
# 4  2017-12-25  '600000  浦发银行  12.59  12.68  12.56  12.61  12.62 -0.03 -0.2377
# 5  2017-12-22  '600000  浦发银行  12.62  12.72  12.61  12.68  12.70 -0.08 -0.6299
# 6  2017-12-21  '600000  浦发银行  12.70  12.78  12.60  12.67  12.73 -0.03 -0.2357
# 7  2017-12-20  '600000  浦发银行  12.73  12.76  12.60  12.76  12.75 -0.02 -0.1569
# 8  2017-12-19  '600000  浦发银行  12.75  12.76  12.62  12.65  12.65  0.10  0.7905
# 9  2017-12-18  '600000  浦发银行  12.65  12.71  12.61  12.71  12.62  0.03  0.2377
#
#       换手率       成交量         成交金额           总市值          流通市值
# ...

# %%
df.describe()
# Out:
#               收盘价         最高价         最低价         开盘价         前收盘         涨跌额  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    14.058484   14.153648   13.947295   14.051557   14.058074    0.000410
# std      1.600742    1.601549    1.611710    1.613532    1.608192    0.143861
# min     12.290000   12.400000   11.720000   11.750000   11.750000   -0.360000
# 25%     12.780000   12.860000   12.630000   12.775000   12.780000   -0.080000
# 50%     13.040000   13.120000   12.920000   13.030000   13.040000   -0.010000
# 75%     15.882500   15.982500   15.775000   15.880000   15.890000    0.060000
# max     16.910000   17.080000   16.810000   16.880000   16.910000    1.180000
#
#               涨跌幅         换手率           成交量          成交金额           总市值  \
# count  244.000000  244.000000  2.440000e+02  2.440000e+02  2.440000e+02
# mean     0.014995    0.150352  3.953515e+07  5.335830e+08  3.602642e+11
# ...

# %%
plt.plot(range(len(df['收盘价'])), df['收盘价'])
plt.title('Closing Price')
# Out:
# Text(0.5,1,'Closing Price')

# %%
plt.plot(range(len(df['开盘价'])), df['开盘价'])
plt.title('Opening Price')
# Out:
# Text(0.5,1,'Opening Price')
